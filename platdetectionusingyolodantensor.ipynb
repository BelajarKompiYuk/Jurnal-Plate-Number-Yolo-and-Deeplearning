# %%
import cv2
import tensorflow as tf
import numpy as np
from tensorflow.keras.applications.inception_v3 import preprocess_input
import os
from ultralytics import YOLO


#import easyocr
#Load EasyOCR reader
#reader = easyocr.Reader(['en'])


# Load YOLOv8 model
model_path = "runs/detect/train4/weights/best.pt"  # Replace with the correct path to your YOLOv8 model
model = YOLO(model_path)

# List of categories
plat = ['AA', 'AB', 'AD', 'AE', 'AG', 'B', 'BE', 'BK', 'BM', 'D', 'DA', 'DH', 'DK', 'E', 'F', 'G', 'H', 'K', 'KB', 'KH', 'KT', 'KU', 'L', 'M', 'N', 'P', 'R', 'S', 'T', 'W']

# Load the trained classification model (InceptionV3 or similar)
classification_model = tf.keras.models.load_model("daerah.keras")

# Define the image size expected by the classification model (299x299)
img_height = 299
img_width = 299

# %%
# Function to preprocess the image specifically for FE-Schrift font
def preprocess_image(image):
    #grayscale_img = img.convert("L")
    
    if len(image.shape) == 3:  # Check if the image has three channels (color image)
        gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    else:
        gray = image  # Already grayscale
        
    #denoised = cv2.bilateralFilter(gray, 11, 17, 17)
    #_, adaptive_thresh = cv2.threshold(denoised, 150, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)

    #if checkwhite(adaptive_thresh):
    #    adaptive_thresh = invert_colors(adaptive_thresh)

    #return adaptive_thresh
    return gray

# Load and preprocess the image for classification prediction
def load_image_for_prediction(img):
    img = cv2.resize(img, (img_width, img_height))  # Resize image to 299x299
    img = np.expand_dims(img, axis=0)  # Add batch dimension
    img = preprocess_input(img)  # Preprocess for InceptionV3 or similar model
    return img

# Predict the class of the cropped plate image
def predict_image(img):
    img_array = load_image_for_prediction(img)
    predictions = classification_model.predict(img_array)
    predicted_class = np.argmax(predictions, axis=1)
    return predicted_class[0]  # Return the predicted class index

# Process frame for license plate detection and classification
def process_frame(frame, outputpath, filename, pos):
    """Process frame for license plate detection and classification."""
    frame = cv2.resize(frame, (1024, 820))  # Resize the image for YOLO detection (if needed)

    # Detect plates using YOLOv8
    results = model(frame)

    i = 1
    for result in results:
        boxes = result.boxes.xyxy.cpu().numpy().astype(int)  # Get bounding boxes in xyxy format
        confidences = result.boxes.conf.cpu().numpy()  # Get confidence scores

        for box, conf in zip(boxes, confidences):
            if conf > 0.5:  # Only consider boxes with confidence > 0.5
                x1, y1, x2, y2 = box
                cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)

                plate_image = frame[y1:y2, x1:x2]  # Crop the plate from the image
                plate_image = cv2.resize(plate_image, (400,200))

                # Resize the cropped plate image for classification
                plate_image1 = plate_image[10:128, 10:95]
                                
                # Use the classification model to predict the class of the plate
                plate_image1 = cv2.resize(plate_image1, (img_width, img_height))
                predicted_class_index = predict_image(plate_image1)
                plate_text1 = plat[predicted_class_index]
                print(" License: ", plate_text1) 

                # Optionally, draw the predicted class on the image
                cv2.putText(frame, plate_text1, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 255, 0), 2)

                # Save the processed plate image
                #cv2.imwrite(outputpath + "/" + filename + "-" + str(pos) + "-" + str(i) + "-L.png", plate_image)

                i += 1

    return frame

# %%
#gambar statis
# Paths
image_folder = "test"  # Folder containing images
output_folder = "testpredict"  # Folder to save output images


# Create the output folder if it does not exist
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# Process all images in the folder
for filename in os.listdir(image_folder):
    if filename.endswith(('.png', '.jpg', '.jpeg')):
        image_path = os.path.join(image_folder, filename)
        image = cv2.imread(image_path)        
        image = process_frame(image, output_folder, filename, 1)

        output_file = os.path.join(output_folder, f"result_{filename}")
        cv2.imwrite(output_file, image)

        #print(f"Processed: {filename}")
        #print("---")

print("Processing complete.")
# Out:
# 0: 512x640 1 license, 358.2ms
# Speed: 15.6ms preprocess, 358.2ms inference, 19.3ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step
#  License:  H
#
# 0: 512x640 1 license, 157.2ms
# Speed: 0.0ms preprocess, 157.2ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step
#  License:  H
#
# 0: 512x640 1 license, 173.0ms
# Speed: 0.0ms preprocess, 173.0ms inference, 14.6ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step
#  License:  H
#
# 0: 512x640 1 license, 204.4ms
# Speed: 0.0ms preprocess, 204.4ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step
#  License:  H
#
# 0: 512x640 1 license, 204.5ms
# Speed: 0.0ms preprocess, 204.5ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step
#  License:  H
#
# 0: 512x640 1 license, 267.5ms
# Speed: 0.0ms preprocess, 267.5ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
#  License:  H
#
# 0: 512x640 1 license, 157.6ms
# Speed: 0.0ms preprocess, 157.6ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step
#  License:  H
#
# 0: 512x640 1 license, 236.3ms
# Speed: 0.0ms preprocess, 236.3ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step
#  License:  H
#
# 0: 512x640 1 license, 188.8ms
# Speed: 0.0ms preprocess, 188.8ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step
#  License:  H
#
# 0: 512x640 1 license, 188.3ms
# Speed: 0.0ms preprocess, 188.3ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step
#  License:  H
#
# 0: 512x640 1 license, 236.4ms
# Speed: 0.0ms preprocess, 236.4ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step
#  License:  B
#
# 0: 512x640 1 license, 173.1ms
# Speed: 0.0ms preprocess, 173.1ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step
#  License:  H
#
# 0: 512x640 1 license, 251.4ms
# Speed: 5.1ms preprocess, 251.4ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step
#  License:  H
#
# 0: 512x640 1 license, 251.3ms
# Speed: 0.0ms preprocess, 251.3ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step
#  License:  H
#
# 0: 512x640 1 license, 188.8ms
# Speed: 0.0ms preprocess, 188.8ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step
#  License:  H
#
# 0: 512x640 1 license, 345.7ms
# Speed: 0.0ms preprocess, 345.7ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step
#  License:  H
#
# 0: 512x640 1 license, 220.0ms
# Speed: 0.0ms preprocess, 220.0ms inference, 3.6ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step
#  License:  H
#
# 0: 512x640 1 license, 252.0ms
# Speed: 15.6ms preprocess, 252.0ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step
#  License:  B
#
# 0: 512x640 1 license, 235.7ms
# Speed: 0.0ms preprocess, 235.7ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step
#  License:  B
#
# 0: 512x640 1 license, 188.8ms
# Speed: 0.0ms preprocess, 188.8ms inference, 15.6ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step
#  License:  H
#
# 0: 512x640 1 license, 267.5ms
# Speed: 0.0ms preprocess, 267.5ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step
#  License:  B
#
# 0: 512x640 1 license, 220.7ms
# Speed: 15.6ms preprocess, 220.7ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step
#  License:  B
#
# 0: 512x640 1 license, 175.0ms
# Speed: 0.0ms preprocess, 175.0ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step
#  License:  B
#
# 0: 512x640 1 license, 204.5ms
# Speed: 15.6ms preprocess, 204.5ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step
#  License:  B
#
# 0: 512x640 1 license, 220.1ms
# Speed: 0.0ms preprocess, 220.1ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step
#  License:  B
#
# 0: 512x640 1 license, 220.1ms
# Speed: 0.0ms preprocess, 220.1ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step
#  License:  B
#
# 0: 512x640 1 license, 203.8ms
# Speed: 0.0ms preprocess, 203.8ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step
#  License:  B
#
# 0: 512x640 1 license, 200.3ms
# Speed: 4.5ms preprocess, 200.3ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step
#  License:  B
#
# 0: 512x640 1 license, 200.6ms
# Speed: 8.6ms preprocess, 200.6ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step
#  License:  B
#
# 0: 512x640 1 license, 235.5ms
# Speed: 0.0ms preprocess, 235.5ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step
#  License:  B
#
# 0: 512x640 1 license, 188.3ms
# Speed: 0.0ms preprocess, 188.3ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
#  License:  B
#
# 0: 512x640 1 license, 283.1ms
# Speed: 0.0ms preprocess, 283.1ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step
#  License:  B
#
# 0: 512x640 1 license, 173.0ms
# Speed: 0.0ms preprocess, 173.0ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 249ms/step
#  License:  B
#
# 0: 512x640 1 license, 173.1ms
# Speed: 15.5ms preprocess, 173.1ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step
#  License:  B
#
# 0: 512x640 2 licenses, 241.6ms
# Speed: 0.0ms preprocess, 241.6ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step
#  License:  B
#
# 0: 512x640 1 license, 157.5ms
# Speed: 0.0ms preprocess, 157.5ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step
#  License:  B
#
# 0: 512x640 1 license, 168.6ms
# Speed: 0.0ms preprocess, 168.6ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step
#  License:  B
#
# 0: 512x640 1 license, 146.3ms
# Speed: 5.1ms preprocess, 146.3ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step
#  License:  B
#
# 0: 512x640 1 license, 180.2ms
# Speed: 2.5ms preprocess, 180.2ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step
#  License:  B
#
# 0: 512x640 1 license, 125.6ms
# Speed: 15.6ms preprocess, 125.6ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
#  License:  B
#
# 0: 512x640 1 license, 141.0ms
# Speed: 0.0ms preprocess, 141.0ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step
#  License:  B
#
# 0: 512x640 1 license, 156.9ms
# Speed: 0.0ms preprocess, 156.9ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step
#  License:  B
#
# 0: 512x640 1 license, 141.0ms
# Speed: 15.6ms preprocess, 141.0ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
#  License:  B
#
# 0: 512x640 1 license, 125.7ms
# Speed: 0.0ms preprocess, 125.7ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step
#  License:  B
#
# 0: 512x640 1 license, 141.6ms
# Speed: 15.6ms preprocess, 141.6ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
#  License:  B
#
# 0: 512x640 1 license, 141.7ms
# Speed: 0.0ms preprocess, 141.7ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step
#  License:  B
#
# 0: 512x640 1 license, 141.3ms
# Speed: 15.6ms preprocess, 141.3ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step
#  License:  B
#
# 0: 512x640 1 license, 204.5ms
# Speed: 0.0ms preprocess, 204.5ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step
#  License:  B
#
# 0: 512x640 1 license, 125.7ms
# Speed: 0.0ms preprocess, 125.7ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step
#  License:  B
#
# 0: 512x640 1 license, 141.8ms
# Speed: 0.0ms preprocess, 141.8ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
#  License:  B
#
# 0: 512x640 1 license, 125.4ms
# Speed: 0.0ms preprocess, 125.4ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step
#  License:  B
#
# 0: 512x640 1 license, 141.2ms
# Speed: 0.0ms preprocess, 141.2ms inference, 15.6ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step
#  License:  B
#
# 0: 512x640 1 license, 172.6ms
# Speed: 0.0ms preprocess, 172.6ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step
#  License:  B
#
# 0: 512x640 1 license, 141.5ms
# Speed: 0.0ms preprocess, 141.5ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step
#  License:  B
#
# 0: 512x640 1 license, 125.5ms
# Speed: 3.6ms preprocess, 125.5ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
#  License:  B
#
# 0: 512x640 1 license, 157.6ms
# Speed: 0.0ms preprocess, 157.6ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step
#  License:  B
#
# 0: 512x640 1 license, 125.7ms
# Speed: 0.0ms preprocess, 125.7ms inference, 15.6ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
#  License:  B
#
# 0: 512x640 1 license, 156.8ms
# Speed: 0.0ms preprocess, 156.8ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
#  License:  B
#
# 0: 512x640 1 license, 122.1ms
# Speed: 0.0ms preprocess, 122.1ms inference, 15.6ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step
#  License:  B
#
# 0: 512x640 1 license, 125.5ms
# Speed: 0.0ms preprocess, 125.5ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step
#  License:  B
#
# 0: 512x640 1 license, 141.2ms
# Speed: 16.0ms preprocess, 141.2ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step
#  License:  B
#
# 0: 512x640 1 license, 141.3ms
# Speed: 15.7ms preprocess, 141.3ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step
#  License:  B
#
# 0: 512x640 1 license, 156.8ms
# Speed: 0.0ms preprocess, 156.8ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
#  License:  B
#
# 0: 512x640 1 license, 141.0ms
# Speed: 15.6ms preprocess, 141.0ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
#  License:  B
#
# 0: 512x640 1 license, 149.9ms
# Speed: 0.0ms preprocess, 149.9ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step
#  License:  B
#
# 0: 512x640 1 license, 172.6ms
# Speed: 0.0ms preprocess, 172.6ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step
#  License:  B
#
# 0: 512x640 1 license, 173.0ms
# Speed: 0.0ms preprocess, 173.0ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step
#  License:  B
#
# 0: 512x640 1 license, 157.0ms
# Speed: 0.0ms preprocess, 157.0ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step
#  License:  B
#
# 0: 512x640 1 license, 157.6ms
# Speed: 0.0ms preprocess, 157.6ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step
#  License:  B
#
# 0: 512x640 1 license, 141.8ms
# Speed: 15.6ms preprocess, 141.8ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step
#  License:  B
#
# 0: 512x640 1 license, 148.8ms
# Speed: 8.5ms preprocess, 148.8ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
#  License:  B
#
# 0: 512x640 1 license, 126.2ms
# Speed: 0.0ms preprocess, 126.2ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
#  License:  B
#
# 0: 512x640 1 license, 125.7ms
# Speed: 0.0ms preprocess, 125.7ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step
#  License:  B
#
# 0: 512x640 1 license, 156.4ms
# Speed: 6.6ms preprocess, 156.4ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
#  License:  B
#
# 0: 512x640 1 license, 141.4ms
# Speed: 15.6ms preprocess, 141.4ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step
#  License:  B
#
# 0: 512x640 1 license, 141.3ms
# Speed: 0.0ms preprocess, 141.3ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
#  License:  B
#
# 0: 512x640 1 license, 158.0ms
# Speed: 0.0ms preprocess, 158.0ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
#  License:  B
#
# 0: 512x640 1 license, 157.5ms
# Speed: 0.0ms preprocess, 157.5ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
#  License:  B
#
# 0: 512x640 1 license, 157.6ms
# Speed: 0.0ms preprocess, 157.6ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
#  License:  B
#
# 0: 512x640 1 license, 121.1ms
# Speed: 0.0ms preprocess, 121.1ms inference, 15.7ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
#  License:  B
#
# 0: 512x640 1 license, 125.4ms
# Speed: 0.0ms preprocess, 125.4ms inference, 7.4ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
#  License:  B
#
# 0: 512x640 1 license, 141.3ms
# Speed: 15.7ms preprocess, 141.3ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
#  License:  B
#
# 0: 512x640 1 license, 156.7ms
# Speed: 0.0ms preprocess, 156.7ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
#  License:  B
#
# 0: 512x640 1 license, 174.6ms
# Speed: 15.7ms preprocess, 174.6ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
#  License:  B
#
# 0: 512x640 1 license, 157.0ms
# Speed: 15.6ms preprocess, 157.0ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
#  License:  B
#
# 0: 512x640 1 license, 141.8ms
# Speed: 0.0ms preprocess, 141.8ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
#  License:  B
#
# 0: 512x640 1 license, 157.4ms
# Speed: 0.0ms preprocess, 157.4ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
#  License:  B
#
# 0: 512x640 2 licenses, 157.5ms
# Speed: 0.0ms preprocess, 157.5ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
#  License:  B
#
# 0: 512x640 1 license, 141.9ms
# Speed: 15.6ms preprocess, 141.9ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
#  License:  B
#
# 0: 512x640 1 license, 134.1ms
# Speed: 0.0ms preprocess, 134.1ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
#  License:  B
#
# 0: 512x640 1 license, 143.4ms
# Speed: 0.0ms preprocess, 143.4ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
#  License:  B
#
# 0: 512x640 1 license, 141.3ms
# Speed: 0.0ms preprocess, 141.3ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step
#  License:  B
#
# 0: 512x640 2 licenses, 141.3ms
# Speed: 0.0ms preprocess, 141.3ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step
#  License:  B
#
# 0: 512x640 1 license, 141.3ms
# Speed: 15.6ms preprocess, 141.3ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
#  License:  B
#
# 0: 512x640 1 license, 153.9ms
# Speed: 0.0ms preprocess, 153.9ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step
#  License:  B
#
# 0: 512x640 2 licenses, 157.6ms
# Speed: 0.0ms preprocess, 157.6ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
#  License:  B
#
# 0: 512x640 1 license, 156.9ms
# Speed: 0.0ms preprocess, 156.9ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
#  License:  B
#
# 0: 512x640 2 licenses, 141.8ms
# Speed: 0.0ms preprocess, 141.8ms inference, 15.7ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
#  License:  B
#
# 0: 512x640 1 license, 141.2ms
# Speed: 0.0ms preprocess, 141.2ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
#  License:  B
#
# 0: 512x640 1 license, 141.4ms
# Speed: 0.0ms preprocess, 141.4ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
#  License:  B
#
# 0: 512x640 1 license, 141.3ms
# Speed: 0.0ms preprocess, 141.3ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
#  License:  B
#
# 0: 512x640 2 licenses, 141.2ms
# Speed: 0.0ms preprocess, 141.2ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
#  License:  B
#
# 0: 512x640 2 licenses, 141.7ms
# Speed: 0.0ms preprocess, 141.7ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step
#  License:  B
#
# 0: 512x640 2 licenses, 157.3ms
# Speed: 0.0ms preprocess, 157.3ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step
#  License:  B
#
# 0: 512x640 2 licenses, 156.8ms
# Speed: 0.0ms preprocess, 156.8ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step
#  License:  B
#
# 0: 512x640 2 licenses, 157.0ms
# Speed: 0.0ms preprocess, 157.0ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
#  License:  B
#
# 0: 512x640 2 licenses, 141.7ms
# Speed: 0.0ms preprocess, 141.7ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
#  License:  B
#
# 0: 512x640 1 license, 140.8ms
# Speed: 0.0ms preprocess, 140.8ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step
#  License:  B
#
# 0: 512x640 2 licenses, 157.0ms
# Speed: 0.0ms preprocess, 157.0ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step
#  License:  B
#
# 0: 512x640 1 license, 131.5ms
# Speed: 0.0ms preprocess, 131.5ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
#  License:  B
#
# 0: 512x640 1 license, 109.7ms
# Speed: 0.0ms preprocess, 109.7ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
#  License:  B
#
# 0: 512x640 2 licenses, 135.1ms
# Speed: 6.6ms preprocess, 135.1ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step
#  License:  B
#
# 0: 512x640 1 license, 157.6ms
# Speed: 0.0ms preprocess, 157.6ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
#  License:  B
#
# 0: 512x640 2 licenses, 173.2ms
# Speed: 0.0ms preprocess, 173.2ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
#  License:  B
#
# 0: 512x640 2 licenses, 140.8ms
# Speed: 0.0ms preprocess, 140.8ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
#  License:  B
#
# 0: 512x640 1 license, 141.4ms
# Speed: 0.0ms preprocess, 141.4ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
#  License:  B
#
# 0: 512x640 1 license, 125.1ms
# Speed: 0.0ms preprocess, 125.1ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
#  License:  B
#
# 0: 512x640 1 license, 149.8ms
# Speed: 0.0ms preprocess, 149.8ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
#  License:  B
#
# 0: 512x640 1 license, 141.3ms
# Speed: 0.0ms preprocess, 141.3ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
#  License:  B
#
# 0: 512x640 1 license, 173.2ms
# Speed: 0.0ms preprocess, 173.2ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
#  License:  B
#
# 0: 512x640 1 license, 141.6ms
# Speed: 0.0ms preprocess, 141.6ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
#  License:  B
#
# 0: 512x640 1 license, 157.5ms
# Speed: 0.0ms preprocess, 157.5ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step
#  License:  B
#
# 0: 512x640 1 license, 141.3ms
# Speed: 0.0ms preprocess, 141.3ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step
#  License:  B
#
# 0: 512x640 1 license, 157.5ms
# Speed: 0.0ms preprocess, 157.5ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
#  License:  B
#
# 0: 512x640 1 license, 157.0ms
# Speed: 15.6ms preprocess, 157.0ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
#  License:  B
#
# 0: 512x640 1 license, 125.4ms
# Speed: 0.0ms preprocess, 125.4ms inference, 5.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
#  License:  B
#
# 0: 512x640 1 license, 125.5ms
# Speed: 15.6ms preprocess, 125.5ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step
#  License:  B
#
# 0: 512x640 1 license, 251.1ms
# Speed: 9.6ms preprocess, 251.1ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
#  License:  B
#
# 0: 512x640 1 license, 156.9ms
# Speed: 0.0ms preprocess, 156.9ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step
#  License:  B
#
# 0: 512x640 2 licenses, 156.9ms
# Speed: 0.0ms preprocess, 156.9ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
#  License:  B
#
# 0: 512x640 2 licenses, 125.7ms
# Speed: 0.0ms preprocess, 125.7ms inference, 15.6ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step
#  License:  B
#
# 0: 512x640 2 licenses, 141.2ms
# Speed: 0.0ms preprocess, 141.2ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
#  License:  B
#
# 0: 512x640 3 licenses, 157.5ms
# Speed: 0.0ms preprocess, 157.5ms inference, 15.7ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step
#  License:  B
#
# 0: 512x640 2 licenses, 157.0ms
# Speed: 0.0ms preprocess, 157.0ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step
#  License:  B
#
# 0: 512x640 2 licenses, 173.1ms
# Speed: 0.0ms preprocess, 173.1ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step
#  License:  B
#
# 0: 512x640 2 licenses, 142.5ms
# Speed: 0.0ms preprocess, 142.5ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
#  License:  B
#
# 0: 512x640 2 licenses, 173.2ms
# Speed: 0.0ms preprocess, 173.2ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
#  License:  B
#
# 0: 512x640 2 licenses, 141.3ms
# Speed: 15.5ms preprocess, 141.3ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
#  License:  B
#
# 0: 512x640 2 licenses, 141.9ms
# Speed: 0.0ms preprocess, 141.9ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
#  License:  B
#
# 0: 512x640 2 licenses, 141.3ms
# Speed: 15.6ms preprocess, 141.3ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
#  License:  B
#
# 0: 512x640 2 licenses, 141.8ms
# Speed: 0.0ms preprocess, 141.8ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
#  License:  B
#
# 0: 512x640 2 licenses, 141.2ms
# Speed: 11.1ms preprocess, 141.2ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
#  License:  B
#
# 0: 512x640 1 license, 159.1ms
# Speed: 0.0ms preprocess, 159.1ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
#  License:  B
#
# 0: 512x640 3 licenses, 141.3ms
# Speed: 0.0ms preprocess, 141.3ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step
#  License:  H
#
# 0: 512x640 2 licenses, 140.4ms
# Speed: 0.0ms preprocess, 140.4ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step
#  License:  B
#
# 0: 512x640 2 licenses, 137.1ms
# Speed: 3.6ms preprocess, 137.1ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step
#  License:  B
#
# 0: 512x640 2 licenses, 150.8ms
# Speed: 0.0ms preprocess, 150.8ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
#  License:  B
#
# 0: 512x640 2 licenses, 110.4ms
# Speed: 10.1ms preprocess, 110.4ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step
#  License:  B
#
# 0: 512x640 1 license, 140.8ms
# Speed: 10.0ms preprocess, 140.8ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step
#  License:  B
#
# 0: 512x640 1 license, 129.4ms
# Speed: 0.0ms preprocess, 129.4ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
#  License:  B
#
# 0: 512x640 2 licenses, 125.4ms
# Speed: 0.0ms preprocess, 125.4ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
#  License:  B
#
# 0: 512x640 2 licenses, 141.3ms
# Speed: 0.0ms preprocess, 141.3ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step
#  License:  B
#
# 0: 512x640 2 licenses, 172.1ms
# Speed: 0.0ms preprocess, 172.1ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step
#  License:  B
#
# 0: 512x640 2 licenses, 157.6ms
# Speed: 0.0ms preprocess, 157.6ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step
#  License:  B
#
# 0: 512x640 2 licenses, 173.1ms
# Speed: 15.6ms preprocess, 173.1ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
#  License:  B
#
# 0: 512x640 2 licenses, 156.5ms
# Speed: 0.0ms preprocess, 156.5ms inference, 15.6ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
#  License:  B
#
# 0: 512x640 2 licenses, 141.9ms
# Speed: 0.0ms preprocess, 141.9ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
#  License:  B
#
# 0: 512x640 2 licenses, 157.4ms
# Speed: 0.0ms preprocess, 157.4ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
#  License:  B
#
# 0: 512x640 2 licenses, 139.0ms
# Speed: 0.0ms preprocess, 139.0ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step
#  License:  B
#
# 0: 512x640 2 licenses, 154.5ms
# Speed: 0.0ms preprocess, 154.5ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step
#  License:  B
#
# 0: 512x640 1 license, 157.6ms
# Speed: 0.0ms preprocess, 157.6ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step
#  License:  B
#
# 0: 512x640 1 license, 141.9ms
# Speed: 15.6ms preprocess, 141.9ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step
#  License:  B
#
# 0: 512x640 2 licenses, 141.3ms
# Speed: 0.0ms preprocess, 141.3ms inference, 15.6ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
#  License:  B
#
# 0: 512x640 1 license, 125.8ms
# Speed: 0.0ms preprocess, 125.8ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
#  License:  B
#
# 0: 512x640 1 license, 123.7ms
# Speed: 2.6ms preprocess, 123.7ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
#  License:  B
#
# 0: 512x640 1 license, 146.5ms
# Speed: 0.0ms preprocess, 146.5ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step
#  License:  B
#
# 0: 512x640 1 license, 141.9ms
# Speed: 0.0ms preprocess, 141.9ms inference, 16.1ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
#  License:  B
#
# 0: 512x640 2 licenses, 141.3ms
# Speed: 0.0ms preprocess, 141.3ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
#  License:  B
#
# 0: 512x640 2 licenses, 141.7ms
# Speed: 0.0ms preprocess, 141.7ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step
#  License:  B
#
# 0: 512x640 2 licenses, 172.4ms
# Speed: 0.0ms preprocess, 172.4ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step
#  License:  B
#
# 0: 512x640 2 licenses, 142.6ms
# Speed: 0.0ms preprocess, 142.6ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step
#  License:  B
#
# 0: 512x640 2 licenses, 141.9ms
# Speed: 0.0ms preprocess, 141.9ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
#  License:  H
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step
#  License:  B
#
# 0: 512x640 1 license, 141.8ms
# Speed: 0.0ms preprocess, 141.8ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
#  License:  B
#
# 0: 512x640 1 license, 157.0ms
# Speed: 0.0ms preprocess, 157.0ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
#  License:  B
#
# 0: 512x640 1 license, 150.4ms
# Speed: 0.0ms preprocess, 150.4ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
#  License:  B
#
# 0: 512x640 1 license, 148.2ms
# Speed: 15.6ms preprocess, 148.2ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
#  License:  B
#
# 0: 512x640 1 license, 141.1ms
# Speed: 0.0ms preprocess, 141.1ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
#  License:  B
#
# 0: 512x640 1 license, 141.2ms
# Speed: 15.7ms preprocess, 141.2ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
#  License:  B
#
# 0: 512x640 2 licenses, 150.9ms
# Speed: 0.0ms preprocess, 150.9ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
#  License:  B
#
# 0: 512x640 2 licenses, 109.8ms
# Speed: 0.0ms preprocess, 109.8ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
#  License:  B
#
# 0: 512x640 2 licenses, 160.2ms
# Speed: 0.0ms preprocess, 160.2ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
#  License:  B
#
# 0: 512x640 2 licenses, 157.0ms
# Speed: 0.0ms preprocess, 157.0ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
#  License:  B
#
# 0: 512x640 1 license, 141.2ms
# Speed: 15.5ms preprocess, 141.2ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
#  License:  B
#
# 0: 512x640 1 license, 165.5ms
# Speed: 0.0ms preprocess, 165.5ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
#  License:  B
#
# 0: 512x640 1 license, 141.3ms
# Speed: 0.0ms preprocess, 141.3ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
#  License:  B
#
# 0: 512x640 1 license, 140.8ms
# Speed: 0.0ms preprocess, 140.8ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step
#  License:  B
#
# 0: 512x640 2 licenses, 156.6ms
# Speed: 15.6ms preprocess, 156.6ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
#  License:  H
#
# 0: 512x640 2 licenses, 141.3ms
# Speed: 0.0ms preprocess, 141.3ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step
#  License:  B
#
# 0: 512x640 1 license, 157.6ms
# Speed: 15.6ms preprocess, 157.6ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step
#  License:  B
#
# 0: 512x640 1 license, 173.2ms
# Speed: 0.0ms preprocess, 173.2ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step
#  License:  B
#
# 0: 512x640 1 license, 147.5ms
# Speed: 0.0ms preprocess, 147.5ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
#  License:  B
#
# 0: 512x640 1 license, 164.1ms
# Speed: 0.0ms preprocess, 164.1ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
#  License:  B
#
# 0: 512x640 1 license, 135.2ms
# Speed: 0.0ms preprocess, 135.2ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step
#  License:  B
#
# 0: 512x640 1 license, 131.9ms
# Speed: 0.0ms preprocess, 131.9ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
#  License:  B
#
# 0: 512x640 1 license, 141.3ms
# Speed: 0.0ms preprocess, 141.3ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step
#  License:  B
#
# 0: 512x640 1 license, 110.7ms
# Speed: 0.0ms preprocess, 110.7ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
#  License:  B
#
# 0: 512x640 1 license, 173.2ms
# Speed: 0.0ms preprocess, 173.2ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
#  License:  B
#
# 0: 512x640 1 license, 157.5ms
# Speed: 0.0ms preprocess, 157.5ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step
#  License:  B
#
# 0: 512x640 1 license, 157.3ms
# Speed: 0.0ms preprocess, 157.3ms inference, 15.6ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
#  License:  B
#
# 0: 512x640 1 license, 157.4ms
# Speed: 0.0ms preprocess, 157.4ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
#  License:  B
#
# 0: 512x640 1 license, 173.1ms
# Speed: 0.0ms preprocess, 173.1ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
#  License:  B
#
# 0: 512x640 1 license, 173.0ms
# Speed: 0.0ms preprocess, 173.0ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step
#  License:  B
#
# 0: 512x640 1 license, 188.8ms
# Speed: 0.0ms preprocess, 188.8ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
#  License:  B
#
# 0: 512x640 1 license, 125.4ms
# Speed: 0.0ms preprocess, 125.4ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
#  License:  B
#
# 0: 512x640 1 license, 172.5ms
# Speed: 0.0ms preprocess, 172.5ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
#  License:  B
#
# 0: 512x640 1 license, 182.6ms
# Speed: 0.0ms preprocess, 182.6ms inference, 6.1ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step
#  License:  B
#
# 0: 512x640 1 license, 125.5ms
# Speed: 0.0ms preprocess, 125.5ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
#  License:  B
#
# 0: 512x640 1 license, 157.3ms
# Speed: 0.0ms preprocess, 157.3ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
#  License:  H
#
# 0: 512x640 1 license, 157.4ms
# Speed: 0.0ms preprocess, 157.4ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
#  License:  H
#
# 0: 512x640 1 license, 141.2ms
# Speed: 0.0ms preprocess, 141.2ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
#  License:  H
#
# 0: 512x640 2 licenses, 141.3ms
# Speed: 0.0ms preprocess, 141.3ms inference, 10.6ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
#  License:  H
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
#  License:  B
#
# 0: 512x640 1 license, 156.9ms
# Speed: 15.7ms preprocess, 156.9ms inference, 15.6ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
#  License:  AD
#
# 0: 512x640 1 license, 157.6ms
# Speed: 0.0ms preprocess, 157.6ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
#  License:  AD
#
# 0: 512x640 1 license, 109.4ms
# Speed: 16.7ms preprocess, 109.4ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step
#  License:  AD
#
# 0: 512x640 1 license, 141.3ms
# Speed: 0.0ms preprocess, 141.3ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step
#  License:  L
#
# 0: 512x640 1 license, 141.4ms
# Speed: 0.0ms preprocess, 141.4ms inference, 15.6ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step
#  License:  H
#
# 0: 512x640 1 license, 125.3ms
# Speed: 0.0ms preprocess, 125.3ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
#  License:  AB
#
# 0: 512x640 1 license, 111.4ms
# Speed: 0.0ms preprocess, 111.4ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
#  License:  AB
#
# 0: 512x640 1 license, 141.8ms
# Speed: 0.0ms preprocess, 141.8ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
#  License:  AB
#
# 0: 512x640 1 license, 157.5ms
# Speed: 0.0ms preprocess, 157.5ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
#  License:  H
#
# 0: 512x640 1 license, 141.2ms
# Speed: 0.0ms preprocess, 141.2ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
#  License:  AD
#
# 0: 512x640 1 license, 157.3ms
# Speed: 15.6ms preprocess, 157.3ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step
#  License:  AD
#
# 0: 512x640 1 license, 141.9ms
# Speed: 0.0ms preprocess, 141.9ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
#  License:  H
#
# 0: 512x640 1 license, 141.2ms
# Speed: 0.0ms preprocess, 141.2ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
#  License:  AD
#
# 0: 512x640 2 licenses, 125.5ms
# Speed: 0.0ms preprocess, 125.5ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step
#  License:  AD
#
# 0: 512x640 1 license, 122.7ms
# Speed: 3.6ms preprocess, 122.7ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
#  License:  AD
#
# 0: 512x640 1 license, 157.6ms
# Speed: 0.0ms preprocess, 157.6ms inference, 15.5ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
#  License:  H
#
# 0: 512x640 1 license, 141.3ms
# Speed: 16.1ms preprocess, 141.3ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step
#  License:  AD
#
# 0: 512x640 1 license, 157.0ms
# Speed: 0.0ms preprocess, 157.0ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step
#  License:  AD
#
# 0: 512x640 1 license, 156.5ms
# Speed: 0.0ms preprocess, 156.5ms inference, 9.1ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
#  License:  AD
#
# 0: 512x640 1 license, 157.0ms
# Speed: 0.0ms preprocess, 157.0ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
#  License:  AD
#
# 0: 512x640 1 license, 141.2ms
# Speed: 0.0ms preprocess, 141.2ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step
#  License:  AD
#
# 0: 512x640 1 license, 127.2ms
# Speed: 14.6ms preprocess, 127.2ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
#  License:  AD
#
# 0: 512x640 1 license, 157.5ms
# Speed: 0.0ms preprocess, 157.5ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step
#  License:  AD
#
# 0: 512x640 1 license, 156.8ms
# Speed: 0.0ms preprocess, 156.8ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
#  License:  AD
#
# 0: 512x640 1 license, 157.5ms
# Speed: 0.0ms preprocess, 157.5ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
#  License:  B
#
# 0: 512x640 1 license, 109.9ms
# Speed: 0.0ms preprocess, 109.9ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
#  License:  H
#
# 0: 512x640 1 license, 142.2ms
# Speed: 0.0ms preprocess, 142.2ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step
#  License:  B
#
# 0: 512x640 1 license, 157.6ms
# Speed: 15.6ms preprocess, 157.6ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step
#  License:  B
#
# 0: 512x640 1 license, 141.3ms
# Speed: 0.0ms preprocess, 141.3ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step
#  License:  B
#
# 0: 512x640 1 license, 173.2ms
# Speed: 0.0ms preprocess, 173.2ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
#  License:  B
#
# 0: 512x640 1 license, 141.9ms
# Speed: 0.0ms preprocess, 141.9ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step
#  License:  B
#
# 0: 512x640 1 license, 147.3ms
# Speed: 0.0ms preprocess, 147.3ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step
#  License:  B
#
# 0: 512x640 1 license, 173.0ms
# Speed: 0.0ms preprocess, 173.0ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step
#  License:  B
#
# 0: 512x640 1 license, 125.7ms
# Speed: 8.6ms preprocess, 125.7ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step
#  License:  B
#
# 0: 512x640 1 license, 141.3ms
# Speed: 15.7ms preprocess, 141.3ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
#  License:  B
#
# 0: 512x640 1 license, 141.3ms
# Speed: 0.0ms preprocess, 141.3ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
#  License:  B
#
# 0: 512x640 1 license, 109.9ms
# Speed: 13.1ms preprocess, 109.9ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step
#  License:  H
#
# 0: 512x640 1 license, 141.0ms
# Speed: 0.0ms preprocess, 141.0ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
#  License:  L
#
# 0: 512x640 1 license, 126.4ms
# Speed: 15.6ms preprocess, 126.4ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step
#  License:  G
#
# ...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step
#  License:  H
#
# 0: 512x640 1 license, 140.2ms
# Speed: 0.0ms preprocess, 140.2ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step
#  License:  H
#
# 0: 512x640 1 license, 150.6ms
# Speed: 0.0ms preprocess, 150.6ms inference, 10.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step
#  License:  H
#
# 0: 512x640 1 license, 140.4ms
# Speed: 9.9ms preprocess, 140.4ms inference, 10.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
#  License:  H
#
# 0: 512x640 1 license, 180.3ms
# Speed: 0.0ms preprocess, 180.3ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step
#  License:  H
#
# 0: 512x640 1 license, 140.9ms
# Speed: 0.0ms preprocess, 140.9ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step
#  License:  H
#
# 0: 512x640 1 license, 140.3ms
# Speed: 10.1ms preprocess, 140.3ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
#  License:  H
#
# 0: 512x640 1 license, 110.1ms
# Speed: 0.0ms preprocess, 110.1ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
#  License:  H
#
# 0: 512x640 1 license, 130.2ms
# Speed: 0.0ms preprocess, 130.2ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step
#  License:  H
#
# 0: 512x640 1 license, 150.3ms
# Speed: 0.0ms preprocess, 150.3ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
#  License:  H
#
# 0: 512x640 1 license, 130.2ms
# Speed: 0.0ms preprocess, 130.2ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step
#  License:  H
#
# 0: 512x640 1 license, 130.3ms
# Speed: 0.0ms preprocess, 130.3ms inference, 10.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step
#  License:  H
#
# 0: 512x640 1 license, 170.3ms
# Speed: 0.0ms preprocess, 170.3ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step
#  License:  H
#
# 0: 512x640 1 license, 130.1ms
# Speed: 10.0ms preprocess, 130.1ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
#  License:  H
#
# 0: 512x640 1 license, 140.4ms
# Speed: 9.9ms preprocess, 140.4ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step
#  License:  H
#
# 0: 512x640 1 license, 130.4ms
# Speed: 0.0ms preprocess, 130.4ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
#  License:  H
#
# 0: 512x640 1 license, 160.6ms
# Speed: 0.0ms preprocess, 160.6ms inference, 10.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step
#  License:  H
#
# 0: 512x640 1 license, 140.6ms
# Speed: 10.0ms preprocess, 140.6ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step
#  License:  H
#
# 0: 512x640 1 license, 140.9ms
# Speed: 10.0ms preprocess, 140.9ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
#  License:  H
#
# 0: 512x640 1 license, 150.8ms
# Speed: 10.0ms preprocess, 150.8ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step
#  License:  H
#
# 0: 512x640 2 licenses, 170.4ms
# Speed: 0.0ms preprocess, 170.4ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
#  License:  H
#
# 0: 512x640 1 license, 120.1ms
# Speed: 0.0ms preprocess, 120.1ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
#  License:  H
#
# 0: 512x640 1 license, 140.7ms
# Speed: 0.0ms preprocess, 140.7ms inference, 10.1ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
#  License:  H
#
# 0: 512x640 1 license, 156.0ms
# Speed: 0.0ms preprocess, 156.0ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step
#  License:  H
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 16
#      14 image_path = os.path.join(image_folder, filename)
#      15 image = cv2.imread(image_path)
# ---> 16 image = process_frame(image, output_folder, filename, 1)
#      18 output_file = os.path.join(output_folder, f"result_{filename}")
#      19 cv2.imwrite(output_file, image)
#
# Cell In[3], line 39, in process_frame(frame, outputpath, filename, pos)
#      36 frame = cv2.resize(frame, (1024, 820))  # Resize the image for YOLO detection (if needed)
#      38 # Detect plates using YOLOv8
# ---> 39 results = model(frame)
#      41 i = 1
#      42 for result in results:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\ultralytics\engine\model.py:176, in Model.__call__(self, source, stream, **kwargs)
#     147 def __call__(
#     148     self,
#     149     source: Union[str, Path, int, Image.Image, list, tuple, np.ndarray, torch.Tensor] = None,
#     150     stream: bool = False,
#     151     **kwargs,
#     152 ) -> list:
#     153     """
#     154     Alias for the predict method, enabling the model instance to be callable for predictions.
#     155
#    (...)
#     174         ...     print(f"Detected {len(r)} objects in image")
#     175     """
# --> 176     return self.predict(source, stream, **kwargs)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\ultralytics\engine\model.py:567, in Model.predict(self, source, stream, predictor, **kwargs)
#     565 if prompts and hasattr(self.predictor, "set_prompts"):  # for SAM-type models
#     566     self.predictor.set_prompts(prompts)
# --> 567 return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\ultralytics\engine\predictor.py:168, in BasePredictor.__call__(self, source, model, stream, *args, **kwargs)
#     166     return self.stream_inference(source, model, *args, **kwargs)
#     167 else:
# --> 168     return list(self.stream_inference(source, model, *args, **kwargs))
#
# File ~\AppData\Roaming\Python\Python312\site-packages\torch\utils\_contextlib.py:36, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      33 try:
#      34     # Issuing `None` to a generator fires it up
#      35     with ctx_factory():
# ---> 36         response = gen.send(None)
#      38     while True:
#      39         try:
#      40             # Forward the response to our caller and get its next request
#
# File ~\AppData\Roaming\Python\Python312\site-packages\ultralytics\engine\predictor.py:254, in BasePredictor.stream_inference(self, source, model, *args, **kwargs)
#     252 # Inference
#     253 with profilers[1]:
# --> 254     preds = self.inference(im, *args, **kwargs)
#     255     if self.args.embed:
#     256         yield from [preds] if isinstance(preds, torch.Tensor) else preds  # yield embedding tensors
#
# File ~\AppData\Roaming\Python\Python312\site-packages\ultralytics\engine\predictor.py:142, in BasePredictor.inference(self, im, *args, **kwargs)
#     136 """Runs inference on a given image using the specified model and arguments."""
#     137 visualize = (
#     138     increment_path(self.save_dir / Path(self.batch[0][0]).stem, mkdir=True)
#     139     if self.args.visualize and (not self.source_type.tensor)
#     140     else False
#     141 )
# --> 142 return self.model(im, augment=self.args.augment, visualize=visualize, embed=self.args.embed, *args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\torch\nn\modules\module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\torch\nn\modules\module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~\AppData\Roaming\Python\Python312\site-packages\ultralytics\nn\autobackend.py:456, in AutoBackend.forward(self, im, augment, visualize, embed)
#     454 # PyTorch
#     455 if self.pt or self.nn_module:
# --> 456     y = self.model(im, augment=augment, visualize=visualize, embed=embed)
#     458 # TorchScript
#     459 elif self.jit:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\torch\nn\modules\module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\torch\nn\modules\module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~\AppData\Roaming\Python\Python312\site-packages\ultralytics\nn\tasks.py:106, in BaseModel.forward(self, x, *args, **kwargs)
#     104 if isinstance(x, dict):  # for cases of training and validating while training.
#     105     return self.loss(x, *args, **kwargs)
# --> 106 return self.predict(x, *args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\ultralytics\nn\tasks.py:124, in BaseModel.predict(self, x, profile, visualize, augment, embed)
#     122 if augment:
#     123     return self._predict_augment(x)
# --> 124 return self._predict_once(x, profile, visualize, embed)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\ultralytics\nn\tasks.py:145, in BaseModel._predict_once(self, x, profile, visualize, embed)
#     143 if profile:
#     144     self._profile_one_layer(m, x, dt)
# --> 145 x = m(x)  # run
#     146 y.append(x if m.i in self.save else None)  # save output
#     147 if visualize:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\torch\nn\modules\module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\torch\nn\modules\module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~\AppData\Roaming\Python\Python312\site-packages\ultralytics\nn\modules\head.py:57, in Detect.forward(self, x)
#      54     return self.forward_end2end(x)
#      56 for i in range(self.nl):
# ---> 57     x[i] = torch.cat((self.cv2[i](x[i]), self.cv3[i](x[i])), 1)
#      58 if self.training:  # Training path
#      59     return x
#
# File ~\AppData\Roaming\Python\Python312\site-packages\torch\nn\modules\module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\torch\nn\modules\module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~\AppData\Roaming\Python\Python312\site-packages\torch\nn\modules\container.py:219, in Sequential.forward(self, input)
#     217 def forward(self, input):
#     218     for module in self:
# --> 219         input = module(input)
#     220     return input
#
# File ~\AppData\Roaming\Python\Python312\site-packages\torch\nn\modules\module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\torch\nn\modules\module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~\AppData\Roaming\Python\Python312\site-packages\ultralytics\nn\modules\conv.py:54, in Conv.forward_fuse(self, x)
#      52 def forward_fuse(self, x):
#      53     """Perform transposed convolution of 2D data."""
# ---> 54     return self.act(self.conv(x))
#
# File ~\AppData\Roaming\Python\Python312\site-packages\torch\nn\modules\module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\torch\nn\modules\module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~\AppData\Roaming\Python\Python312\site-packages\torch\nn\modules\conv.py:458, in Conv2d.forward(self, input)
#     457 def forward(self, input: Tensor) -> Tensor:
# --> 458     return self._conv_forward(input, self.weight, self.bias)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\torch\nn\modules\conv.py:454, in Conv2d._conv_forward(self, input, weight, bias)
#     450 if self.padding_mode != 'zeros':
#     451     return F.conv2d(F.pad(input, self._reversed_padding_repeated_twice, mode=self.padding_mode),
#     452                     weight, bias, self.stride,
#     453                     _pair(0), self.dilation, self.groups)
# --> 454 return F.conv2d(input, weight, bias, self.stride,
#     455                 self.padding, self.dilation, self.groups)
#
# KeyboardInterrupt:

# %%
fourcc = cv2.VideoWriter_fourcc(*'XVID')
outputpath = "testpredict"
filename = '20240911_074146'
out = cv2.VideoWriter(outputpath + "/" + filename + ".avi", fourcc, 20.0, (1024, 820))


x, y, w, h = 10, 600, 2500, 2500  # Adjust these values as neede

# Use OpenCV to capture video from a file or webcam
video_path = "test/"+filename + ".mp4"  # If using a video file
cap = cv2.VideoCapture(video_path)  # For a video file
# cap = cv2.VideoCapture(0)  # Uncomment this line to use the webcam instead

# Check if the video capture opened successfully
if not cap.isOpened():
    print("Error: Could not open video.")
    exit()
    
frame_count = 0
pos = 1
# Loop over the frames of the video
while True:
    ret, frame = cap.read()
    
    if not ret:
        print("Error: Could not read frame.")
        break

    #frame_count += 1
    #if frame_count % 3 != 0:  # Adjust this number to skip frames
    #    continue
    
    #croper
    frame = process_frame(frame, outputpath, filename, pos)
    out.write(frame)
    pos = pos + 1
    
    # Display the frame with bounding boxes
    cv2.imshow('YOLOv5 Object Detection', frame)

    # Exit the loop if the 'q' key is pressed
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the video capture and close windows
cap.release()
out.release()
cv2.destroyAllWindows()
# Out:
# 0: 512x640 1 license, 189.0ms
# Speed: 15.6ms preprocess, 189.0ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 license, 47.5ms
# Speed: 0.0ms preprocess, 47.5ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 license, 63.0ms
# Speed: 0.0ms preprocess, 63.0ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
#  License:  B
#
# 0: 512x640 1 license, 47.3ms
# Speed: 0.0ms preprocess, 47.3ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 license, 47.5ms
# Speed: 0.0ms preprocess, 47.5ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#  License:  B
#
# 0: 512x640 1 license, 47.1ms
# Speed: 0.0ms preprocess, 47.1ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#  License:  B
#
# 0: 512x640 1 license, 44.0ms
# Speed: 0.0ms preprocess, 44.0ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
#
# 0: 512x640 1 license, 47.7ms
# Speed: 0.0ms preprocess, 47.7ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#  License:  B
#
# 0: 512x640 2 licenses, 47.2ms
# Speed: 0.0ms preprocess, 47.2ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
#
# 0: 512x640 2 licenses, 49.9ms
# Speed: 0.0ms preprocess, 49.9ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
#  License:  B
#
# 0: 512x640 2 licenses, 47.5ms
# Speed: 0.0ms preprocess, 47.5ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
#  License:  B
#
# 0: 512x640 2 licenses, 47.2ms
# Speed: 0.0ms preprocess, 47.2ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#  License:  B
#
# 0: 512x640 2 licenses, 47.3ms
# Speed: 0.0ms preprocess, 47.3ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
#  License:  B
#
# 0: 512x640 2 licenses, 47.0ms
# Speed: 0.0ms preprocess, 47.0ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
#
# 0: 512x640 2 licenses, 49.6ms
# Speed: 0.0ms preprocess, 49.6ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
#
# 0: 512x640 2 licenses, 47.6ms
# Speed: 0.0ms preprocess, 47.6ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
#  License:  B
#
# 0: 512x640 2 licenses, 47.3ms
# Speed: 0.0ms preprocess, 47.3ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
#
# 0: 512x640 2 licenses, 53.8ms
# Speed: 0.0ms preprocess, 53.8ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
#
# 0: 512x640 5 licenses, 47.2ms
# Speed: 0.0ms preprocess, 47.2ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
#
# 0: 512x640 4 licenses, 47.3ms
# Speed: 0.0ms preprocess, 47.3ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
#
# 0: 512x640 4 licenses, 47.2ms
# Speed: 0.0ms preprocess, 47.2ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
#
# 0: 512x640 4 licenses, 47.2ms
# Speed: 0.0ms preprocess, 47.2ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
#
# 0: 512x640 5 licenses, 48.4ms
# Speed: 0.0ms preprocess, 48.4ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
#
# 0: 512x640 2 licenses, 46.9ms
# Speed: 0.0ms preprocess, 46.9ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
#
# 0: 512x640 4 licenses, 50.0ms
# Speed: 0.0ms preprocess, 50.0ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
#  License:  B
#
# 0: 512x640 3 licenses, 46.9ms
# Speed: 0.0ms preprocess, 46.9ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
#  License:  B
#
# 0: 512x640 2 licenses, 46.8ms
# Speed: 0.0ms preprocess, 46.8ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
#  License:  B
#
# 0: 512x640 2 licenses, 47.3ms
# Speed: 0.0ms preprocess, 47.3ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
#
# 0: 512x640 3 licenses, 47.2ms
# Speed: 0.0ms preprocess, 47.2ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
#  License:  B
#
# 0: 512x640 2 licenses, 46.8ms
# Speed: 0.0ms preprocess, 46.8ms inference, 6.5ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
#
# 0: 512x640 3 licenses, 46.8ms
# Speed: 0.0ms preprocess, 46.8ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#  License:  B
#
# 0: 512x640 3 licenses, 47.3ms
# Speed: 0.0ms preprocess, 47.3ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
#  License:  B
#
# 0: 512x640 3 licenses, 47.3ms
# Speed: 0.0ms preprocess, 47.3ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
#
# 0: 512x640 3 licenses, 44.3ms
# Speed: 0.0ms preprocess, 44.3ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
#
# 0: 512x640 3 licenses, 46.8ms
# Speed: 0.0ms preprocess, 46.8ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
#  License:  B
#
# 0: 512x640 3 licenses, 46.9ms
# Speed: 0.0ms preprocess, 46.9ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
#  License:  B
#
# 0: 512x640 3 licenses, 47.3ms
# Speed: 0.0ms preprocess, 47.3ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
#  License:  B
#
# 0: 512x640 3 licenses, 47.4ms
# Speed: 0.0ms preprocess, 47.4ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
#
# 0: 512x640 2 licenses, 47.2ms
# Speed: 0.0ms preprocess, 47.2ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
#
# 0: 512x640 2 licenses, 47.1ms
# Speed: 0.0ms preprocess, 47.1ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
#
# 0: 512x640 2 licenses, 46.9ms
# Speed: 0.0ms preprocess, 46.9ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
#
# 0: 512x640 3 licenses, 46.9ms
# Speed: 0.0ms preprocess, 46.9ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
#
# 0: 512x640 4 licenses, 47.4ms
# Speed: 0.0ms preprocess, 47.4ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
#
# 0: 512x640 3 licenses, 47.3ms
# Speed: 0.0ms preprocess, 47.3ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
#
# 0: 512x640 3 licenses, 46.8ms
# Speed: 0.0ms preprocess, 46.8ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#  License:  B
#
# 0: 512x640 3 licenses, 46.0ms
# Speed: 0.0ms preprocess, 46.0ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
#
# 0: 512x640 3 licenses, 47.7ms
# Speed: 0.0ms preprocess, 47.7ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
#
# 0: 512x640 4 licenses, 43.8ms
# Speed: 0.0ms preprocess, 43.8ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#  License:  B
#
# 0: 512x640 3 licenses, 47.7ms
# Speed: 0.0ms preprocess, 47.7ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
#
# 0: 512x640 3 licenses, 46.9ms
# Speed: 0.0ms preprocess, 46.9ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
#  License:  B
#
# 0: 512x640 3 licenses, 46.9ms
# Speed: 0.0ms preprocess, 46.9ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
#  License:  B
#
# 0: 512x640 4 licenses, 46.9ms
# Speed: 0.0ms preprocess, 46.9ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
#  License:  B
#
# 0: 512x640 3 licenses, 46.9ms
# Speed: 0.0ms preprocess, 46.9ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#  License:  H
#
# 0: 512x640 3 licenses, 46.9ms
# Speed: 0.0ms preprocess, 46.9ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
#  License:  B
#
# 0: 512x640 3 licenses, 46.8ms
# Speed: 0.0ms preprocess, 46.8ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
#  License:  B
#
# 0: 512x640 3 licenses, 46.8ms
# Speed: 0.0ms preprocess, 46.8ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
#
# 0: 512x640 3 licenses, 46.7ms
# Speed: 0.0ms preprocess, 46.7ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
#
# 0: 512x640 3 licenses, 46.8ms
# Speed: 0.0ms preprocess, 46.8ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
#  License:  B
#
# 0: 512x640 3 licenses, 47.3ms
# Speed: 0.0ms preprocess, 47.3ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
#  License:  B
#
# 0: 512x640 3 licenses, 46.8ms
# Speed: 0.0ms preprocess, 46.8ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
#
# 0: 512x640 2 licenses, 47.1ms
# Speed: 0.0ms preprocess, 47.1ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
#  License:  B
#
# 0: 512x640 3 licenses, 47.3ms
# Speed: 0.0ms preprocess, 47.3ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
#  License:  B
#
# 0: 512x640 2 licenses, 45.3ms
# Speed: 0.0ms preprocess, 45.3ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
#
# 0: 512x640 3 licenses, 46.9ms
# Speed: 0.0ms preprocess, 46.9ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#  License:  B
#
# 0: 512x640 2 licenses, 46.8ms
# Speed: 0.0ms preprocess, 46.8ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
#
# 0: 512x640 2 licenses, 47.3ms
# Speed: 0.0ms preprocess, 47.3ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
#  License:  B
#
# 0: 512x640 2 licenses, 47.3ms
# Speed: 0.0ms preprocess, 47.3ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
#
# 0: 512x640 2 licenses, 38.8ms
# Speed: 5.1ms preprocess, 38.8ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
#
# 0: 512x640 2 licenses, 47.3ms
# Speed: 0.0ms preprocess, 47.3ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#  License:  B
#
# 0: 512x640 2 licenses, 47.4ms
# Speed: 0.0ms preprocess, 47.4ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
#
# 0: 512x640 3 licenses, 47.6ms
# Speed: 0.0ms preprocess, 47.6ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
#  License:  B
#
# 0: 512x640 3 licenses, 47.8ms
# Speed: 0.0ms preprocess, 47.8ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
#  License:  B
#
# 0: 512x640 3 licenses, 46.8ms
# Speed: 0.0ms preprocess, 46.8ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
#
# 0: 512x640 3 licenses, 46.9ms
# Speed: 0.0ms preprocess, 46.9ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
#
# 0: 512x640 3 licenses, 46.8ms
# Speed: 0.0ms preprocess, 46.8ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#  License:  B
#
# 0: 512x640 3 licenses, 48.9ms
# Speed: 0.0ms preprocess, 48.9ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  H
#
# 0: 512x640 2 licenses, 49.5ms
# Speed: 0.0ms preprocess, 49.5ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
#  License:  B
#
# 0: 512x640 2 licenses, 47.7ms
# Speed: 0.0ms preprocess, 47.7ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
#  License:  B
#
# 0: 512x640 3 licenses, 46.9ms
# Speed: 0.0ms preprocess, 46.9ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
#
# 0: 512x640 2 licenses, 46.9ms
# Speed: 0.0ms preprocess, 46.9ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
#
# 0: 512x640 1 license, 47.4ms
# Speed: 0.0ms preprocess, 47.4ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
#  License:  B
#
# 0: 512x640 1 license, 31.3ms
# Speed: 0.0ms preprocess, 31.3ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
#  License:  B
#
# 0: 512x640 1 license, 47.4ms
# Speed: 0.0ms preprocess, 47.4ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
#  License:  B
#
# 0: 512x640 1 license, 46.9ms
# Speed: 0.0ms preprocess, 46.9ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
#  License:  B
#
# 0: 512x640 1 license, 46.9ms
# Speed: 0.0ms preprocess, 46.9ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
#  License:  B
#
# 0: 512x640 1 license, 47.4ms
# Speed: 0.0ms preprocess, 47.4ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
#  License:  B
#
# 0: 512x640 2 licenses, 46.8ms
# Speed: 0.0ms preprocess, 46.8ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
#
# 0: 512x640 2 licenses, 47.4ms
# Speed: 0.0ms preprocess, 47.4ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
#  License:  B
#
# 0: 512x640 2 licenses, 46.9ms
# Speed: 0.0ms preprocess, 46.9ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
#
# 0: 512x640 2 licenses, 47.4ms
# Speed: 0.0ms preprocess, 47.4ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
#  License:  B
#
# 0: 512x640 1 license, 47.4ms
# Speed: 0.0ms preprocess, 47.4ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#  License:  B
#
# 0: 512x640 (no detections), 47.1ms
# Speed: 0.0ms preprocess, 47.1ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 license, 47.3ms
# Speed: 0.0ms preprocess, 47.3ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 license, 29.9ms
# Speed: 7.1ms preprocess, 29.9ms inference, 10.5ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
#  License:  B
#
# 0: 512x640 3 licenses, 46.9ms
# Speed: 0.0ms preprocess, 46.9ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
#
# 0: 512x640 2 licenses, 46.8ms
# Speed: 0.0ms preprocess, 46.8ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
#  License:  B
#
# 0: 512x640 3 licenses, 46.9ms
# Speed: 0.0ms preprocess, 46.9ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
#  License:  B
#
# 0: 512x640 3 licenses, 47.3ms
# Speed: 0.0ms preprocess, 47.3ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
#  License:  B
#
# 0: 512x640 3 licenses, 40.8ms
# Speed: 6.5ms preprocess, 40.8ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
#
# 0: 512x640 3 licenses, 46.9ms
# Speed: 0.0ms preprocess, 46.9ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#  License:  B
#
# 0: 512x640 3 licenses, 46.9ms
# Speed: 0.0ms preprocess, 46.9ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
#
# 0: 512x640 3 licenses, 47.3ms
# Speed: 0.0ms preprocess, 47.3ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
#
# 0: 512x640 3 licenses, 47.3ms
# Speed: 0.0ms preprocess, 47.3ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
#  License:  B
#
# 0: 512x640 3 licenses, 47.3ms
# Speed: 0.0ms preprocess, 47.3ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
#
# 0: 512x640 3 licenses, 47.2ms
# Speed: 0.0ms preprocess, 47.2ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
#  License:  B
#
# 0: 512x640 3 licenses, 47.6ms
# Speed: 0.0ms preprocess, 47.6ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
#  License:  B
#
# 0: 512x640 3 licenses, 47.5ms
# Speed: 0.0ms preprocess, 47.5ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
#
# 0: 512x640 3 licenses, 46.6ms
# Speed: 0.0ms preprocess, 46.6ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
#  License:  B
#
# 0: 512x640 3 licenses, 45.3ms
# Speed: 0.0ms preprocess, 45.3ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
#  License:  B
#
# 0: 512x640 3 licenses, 46.9ms
# Speed: 0.0ms preprocess, 46.9ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
#  License:  B
#
# 0: 512x640 3 licenses, 46.8ms
# Speed: 0.0ms preprocess, 46.8ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
#
# 0: 512x640 3 licenses, 52.7ms
# Speed: 0.0ms preprocess, 52.7ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
#  License:  B
#
# 0: 512x640 3 licenses, 47.2ms
# Speed: 0.0ms preprocess, 47.2ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
#
# 0: 512x640 3 licenses, 46.9ms
# Speed: 0.0ms preprocess, 46.9ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
#  License:  B
#
# 0: 512x640 3 licenses, 46.8ms
# Speed: 0.0ms preprocess, 46.8ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
#
# 0: 512x640 3 licenses, 46.8ms
# Speed: 0.0ms preprocess, 46.8ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
#  License:  B
#
# 0: 512x640 3 licenses, 49.5ms
# Speed: 0.0ms preprocess, 49.5ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
#  License:  B
#
# 0: 512x640 3 licenses, 47.2ms
# Speed: 0.0ms preprocess, 47.2ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
#
# 0: 512x640 3 licenses, 47.3ms
# Speed: 0.0ms preprocess, 47.3ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
#
# 0: 512x640 4 licenses, 46.9ms
# Speed: 0.0ms preprocess, 46.9ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#  License:  B
#
# 0: 512x640 4 licenses, 47.5ms
# Speed: 0.0ms preprocess, 47.5ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
#  License:  H
#
# 0: 512x640 4 licenses, 47.7ms
# Speed: 0.0ms preprocess, 47.7ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  L
#
# 0: 512x640 3 licenses, 47.8ms
# Speed: 0.0ms preprocess, 47.8ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
#  License:  H
#
# 0: 512x640 3 licenses, 44.4ms
# Speed: 0.0ms preprocess, 44.4ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
#
# 0: 512x640 3 licenses, 47.2ms
# Speed: 0.0ms preprocess, 47.2ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
#  License:  B
#
# 0: 512x640 3 licenses, 54.3ms
# Speed: 0.0ms preprocess, 54.3ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#  License:  B
#
# 0: 512x640 3 licenses, 47.1ms
# Speed: 0.0ms preprocess, 47.1ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
#  License:  B
#
# 0: 512x640 3 licenses, 47.2ms
# Speed: 0.0ms preprocess, 47.2ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
#  License:  B
#
# 0: 512x640 3 licenses, 46.9ms
# Speed: 0.0ms preprocess, 46.9ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
#
# 0: 512x640 3 licenses, 46.9ms
# Speed: 0.0ms preprocess, 46.9ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
#
# 0: 512x640 4 licenses, 46.8ms
# Speed: 0.0ms preprocess, 46.8ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
#
# 0: 512x640 3 licenses, 46.8ms
# Speed: 0.0ms preprocess, 46.8ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
#  License:  B
#
# 0: 512x640 4 licenses, 47.3ms
# Speed: 0.0ms preprocess, 47.3ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
#  License:  B
#
# 0: 512x640 3 licenses, 47.3ms
# Speed: 0.0ms preprocess, 47.3ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
#
# 0: 512x640 3 licenses, 47.3ms
# Speed: 0.0ms preprocess, 47.3ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
#  License:  B
#
# 0: 512x640 3 licenses, 42.4ms
# Speed: 0.0ms preprocess, 42.4ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
#
# 0: 512x640 3 licenses, 46.9ms
# Speed: 0.0ms preprocess, 46.9ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#  License:  B
#
# 0: 512x640 3 licenses, 46.8ms
# Speed: 0.0ms preprocess, 46.8ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
#
# 0: 512x640 3 licenses, 46.9ms
# Speed: 0.0ms preprocess, 46.9ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
#
# 0: 512x640 3 licenses, 46.9ms
# Speed: 0.0ms preprocess, 46.9ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#  License:  B
# Error: Could not read frame.
